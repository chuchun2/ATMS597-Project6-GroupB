# %% [markdown]
# <a href="https://colab.research.google.com/github/chuchun2/ATMS597-Project6-GroupB/blob/master/ATMS597_Project6_GroupB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pylab inline
import xarray as xr
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from math import sqrt
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['sqrt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
# Set your directory path
YOUR_DIRECTORY = '/content/drive/My Drive/ATMS597 Weather Climate Data Analysis/Module 6/Project 6/'  # Chu-Chun
# YOUR_DIRECTORY = '/content/drive/My Drive/Colab Notebooks/Project_6/' # Jeff

# %%
# Load saved combined data
AR_MJOIndices_df = pd.read_csv(YOUR_DIRECTORY + 'AR_MJOIndices_v1.csv', index_col = 'Unnamed: 0')
UR_MJOIndices_df = pd.read_csv(YOUR_DIRECTORY + 'UR_MJOIndices_v1.csv', index_col = 'Unnamed: 0')
AR_MJOIndices_df.columns.name = 'Date'
UR_MJOIndices_df.columns.name = 'Date'
AR_MJOIndices_df.index = pd.to_datetime(AR_MJOIndices_df.index)
UR_MJOIndices_df.index = pd.to_datetime(UR_MJOIndices_df.index)

# %%
# Add year, month, day as features
AR_MJOIndices_df['Year'] = AR_MJOIndices_df.index.year
AR_MJOIndices_df['Month'] = AR_MJOIndices_df.index.month
AR_MJOIndices_df['Day'] = AR_MJOIndices_df.index.day

UR_MJOIndices_df['Year'] = UR_MJOIndices_df.index.year
UR_MJOIndices_df['Month'] = UR_MJOIndices_df.index.month
UR_MJOIndices_df['Day'] = UR_MJOIndices_df.index.day

# Select only Oct-Mar
# AR_MJOIndices_df = AR_MJOIndices_df[~AR_MJOIndices_df.index.month.isin([4, 5, 6, 7, 8, 9])]
# UR_MJOIndices_df = UR_MJOIndices_df[~UR_MJOIndices_df.index.month.isin([4, 5, 6, 7, 8, 9])]

# %%
AR_MJOIndices_df
# Out:
# Date        AR_PRCP  AR_TMAX  AR_TMIN  ...  Year  Month  Day
# 1980-01-01      0.0     30.8     11.2  ...  1980      1    1
# 1980-01-02      0.0     28.4     19.9  ...  1980      1    2
# 1980-01-03      0.0     27.4     10.8  ...  1980      1    3
# 1980-01-04      0.0     32.8     17.3  ...  1980      1    4
# 1980-01-05     18.0     28.2     17.3  ...  1980      1    5
# ...             ...      ...      ...  ...   ...    ...  ...
# 2019-12-27      NaN      NaN     21.0  ...  2019     12   27
# 2019-12-28      0.0     36.0      NaN  ...  2019     12   28
# 2019-12-29      NaN      NaN     13.0  ...  2019     12   29
# 2019-12-30      5.1     35.2      NaN  ...  2019     12   30
# 2019-12-31     11.9     32.7     17.5  ...  2019     12   31
#
# [14610 rows x 34 columns]

# %%
UR_MJOIndices_df
# Out:
# Date        UR_PRCP  UR_TMAX  UR_TMIN  ...  Year  Month  Day
# 1980-01-01      NaN      NaN      NaN  ...  1980      1    1
# 1980-01-02      NaN      NaN      NaN  ...  1980      1    2
# 1980-01-03      NaN      NaN      NaN  ...  1980      1    3
# 1980-01-04      NaN      NaN      NaN  ...  1980      1    4
# 1980-01-05      NaN      NaN      NaN  ...  1980      1    5
# ...             ...      ...      ...  ...   ...    ...  ...
# 2019-12-27      0.0      NaN     20.6  ...  2019     12   27
# 2019-12-28      0.0     38.8      NaN  ...  2019     12   28
# 2019-12-29     32.5     38.5     20.2  ...  2019     12   29
# 2019-12-30      0.0     36.4     23.4  ...  2019     12   30
# 2019-12-31      NaN      NaN      NaN  ...  2019     12   31
#
# [14610 rows x 34 columns]

# %% [markdown]
# # (1) AR_PRCP linear regression

# %%
# clean the data
data = AR_MJOIndices_df.drop(columns = ['AR_TMAX', 'AR_TMIN'])
data = data.dropna()
data
# Out:
# Date        AR_PRCP  MJOPhase_OLR  MJOAmplitude_OLR  ...  Year  Month  Day
# 1980-01-31      0.0             6            0.3975  ...  1980      1   31
# 1980-02-01      0.0             7            0.6582  ...  1980      2    1
# 1980-02-02      1.0             8            0.7567  ...  1980      2    2
# 1980-02-03      3.0             8            0.8586  ...  1980      2    3
# 1980-02-04      0.0             7            0.8608  ...  1980      2    4
# ...             ...           ...               ...  ...   ...    ...  ...
# 2019-12-20      2.0             4            0.5752  ...  2019     12   20
# 2019-12-21      0.0             5            0.5292  ...  2019     12   21
# 2019-12-28      0.0             7            0.8633  ...  2019     12   28
# 2019-12-30      5.1             8            0.6520  ...  2019     12   30
# 2019-12-31     11.9             1            0.4188  ...  2019     12   31
#
# [6990 rows x 32 columns]

# %%
from sklearn.preprocessing import normalize

# Separate observation precipitation and features
y = data['AR_PRCP'].to_numpy()
X = data.drop(columns = ['AR_PRCP']).to_numpy()
X_norm = (X - mean(X, axis=0)) / std(X, axis=0)

# Split the data into training and testing sets
train_X, test_X, train_y, test_y = train_test_split(X_norm, y, test_size = 0.3, random_state = 42)

# Linear regression model
model_LinearRegression = LinearRegression()
model_LinearRegression.fit(train_X, train_y)

LinearRegression_predict_y = model_LinearRegression.predict(test_X)
rmse_LinearRegression = sqrt(mean_squared_error(test_y, LinearRegression_predict_y))
print('RMSE of linear regression model: ', rmse_LinearRegression)

# Plot testing data and model prediction
plt.plot(test_y, '.', color='r', label='Observed')
plt.plot(LinearRegression_predict_y, '-', color='b', label='Predicted')
plt.legend(loc='upper left')
plt.xlabel('Data Points')
plt.ylabel('Total Precipitation (mm)')
plt.tight_layout()
plt.savefig(YOUR_DIRECTORY + 'LinearRegression_AR_PRCP.png', dpi=600)
# Out:
# RMSE of linear regression model:  7.589412123358342

# %%
plt.figure(figsize=(22, 4.5))
plt.plot(model_LinearRegression.coef_, '.-')
plt.grid()

# %% [markdown]
# # (2) AR_TMAX linear regression

# %%
# clean the data
data = AR_MJOIndices_df.drop(columns = ['AR_PRCP', 'AR_TMIN'])
data = data.dropna()
data
# Out:
# Date        AR_TMAX  MJOPhase_OLR  MJOAmplitude_OLR  ...  Year  Month  Day
# 1980-01-31     22.6             6            0.3975  ...  1980      1   31
# 1980-02-01     32.6             7            0.6582  ...  1980      2    1
# 1980-02-02     32.6             8            0.7567  ...  1980      2    2
# 1980-02-03     33.0             8            0.8586  ...  1980      2    3
# 1980-02-04     34.2             7            0.8608  ...  1980      2    4
# ...             ...           ...               ...  ...   ...    ...  ...
# 2019-12-20     30.5             4            0.5752  ...  2019     12   20
# 2019-12-24     36.8             5            1.0406  ...  2019     12   24
# 2019-12-28     36.0             7            0.8633  ...  2019     12   28
# 2019-12-30     35.2             8            0.6520  ...  2019     12   30
# 2019-12-31     32.7             1            0.4188  ...  2019     12   31
#
# [11141 rows x 32 columns]

# %%
# Separate observation precipitation and features
y = data['AR_TMAX'].to_numpy()
X = data.drop(columns = ['AR_TMAX']).to_numpy()
X_norm = (X - mean(X, axis=0)) / std(X, axis=0)

# Split the data into training and testing sets
train_X, test_X, train_y, test_y = train_test_split(X_norm, y, test_size = 0.3, random_state = 42)

# Linear regression model
model_LinearRegression = LinearRegression()
model_LinearRegression.fit(train_X, train_y)

LinearRegression_predict_y = model_LinearRegression.predict(test_X)
rmse_LinearRegression = sqrt(mean_squared_error(test_y, LinearRegression_predict_y))
print('RMSE of linear regression model: ', rmse_LinearRegression)

# Plot testing data and model prediction
plt.plot(test_y, '.', color='r', label='Observed')
plt.plot(LinearRegression_predict_y, '-', color='b', label='Predicted')
plt.legend(loc='upper left')
plt.xlabel('Data Points')
plt.ylabel('Maximum Temperature (C)')
plt.tight_layout()
plt.savefig(YOUR_DIRECTORY + 'LinearRegression_AR_TMAX.png', dpi=600)
# Out:
# RMSE of linear regression model:  6.11702691124793

# %%
plt.figure(figsize=(22, 4.5))
plt.plot(model_LinearRegression.coef_, '.-')
plt.grid()

# %% [markdown]
# # (3) AR_TMIN linear regression

# %%
# clean the data
data = AR_MJOIndices_df.drop(columns = ['AR_PRCP', 'AR_TMAX'])
data = data.dropna()
data
# Out:
# Date        AR_TMIN  MJOPhase_OLR  MJOAmplitude_OLR  ...  Year  Month  Day
# 1980-01-31     15.2             6            0.3975  ...  1980      1   31
# 1980-02-01      9.9             7            0.6582  ...  1980      2    1
# 1980-02-02     22.3             8            0.7567  ...  1980      2    2
# 1980-02-03     19.5             8            0.8586  ...  1980      2    3
# 1980-02-04     19.0             7            0.8608  ...  1980      2    4
# ...             ...           ...               ...  ...   ...    ...  ...
# 2019-12-25     10.8             6            1.3163  ...  2019     12   25
# 2019-12-26     13.1             6            1.2575  ...  2019     12   26
# 2019-12-27     21.0             6            1.1587  ...  2019     12   27
# 2019-12-29     13.0             7            0.8687  ...  2019     12   29
# 2019-12-31     17.5             1            0.4188  ...  2019     12   31
#
# [13431 rows x 32 columns]

# %%
# Separate observation precipitation and features
y = data['AR_TMIN'].to_numpy()
X = data.drop(columns = ['AR_TMIN']).to_numpy()
X_norm = (X - mean(X, axis=0)) / std(X, axis=0)

# Split the data into training and testing sets
train_X, test_X, train_y, test_y = train_test_split(X_norm, y, test_size = 0.3, random_state = 42)

# Linear regression model
model_LinearRegression = LinearRegression()
model_LinearRegression.fit(train_X, train_y)

LinearRegression_predict_y = model_LinearRegression.predict(test_X)
rmse_LinearRegression = sqrt(mean_squared_error(test_y, LinearRegression_predict_y))
print('RMSE of linear regression model: ', rmse_LinearRegression)

# Plot testing data and model prediction
plt.plot(test_y, '.', color='r', label='Observed')
plt.plot(LinearRegression_predict_y, '-', color='b', label='Predicted')
plt.legend(loc='upper left')
plt.xlabel('Data Points')
plt.ylabel('Minimum Temperature (C)')
plt.tight_layout()
plt.savefig(YOUR_DIRECTORY + 'LinearRegression_AR_TMIN.png', dpi=600)
# Out:
# RMSE of linear regression model:  5.734515158247746

# %%
plt.figure(figsize=(22, 4.5))
plt.plot(model_LinearRegression.coef_, '.-')
plt.grid()

# %% [markdown]
# # (4) UR_PRCP linear regression

# %%
# clean the data
data = UR_MJOIndices_df.drop(columns = ['UR_TMAX', 'UR_TMIN'])
data = data.dropna()
data
# Out:
# Date        UR_PRCP  MJOPhase_OLR  MJOAmplitude_OLR  ...  Year  Month  Day
# 1980-01-31      0.3             6            0.3975  ...  1980      1   31
# 1980-02-01     15.0             7            0.6582  ...  1980      2    1
# 1980-02-02      0.0             8            0.7567  ...  1980      2    2
# 1980-02-03      0.0             8            0.8586  ...  1980      2    3
# 1980-02-18      0.0             8            1.0633  ...  1980      2   18
# ...             ...           ...               ...  ...   ...    ...  ...
# 2019-12-26      0.0             6            1.2575  ...  2019     12   26
# 2019-12-27      0.0             6            1.1587  ...  2019     12   27
# 2019-12-28      0.0             7            0.8633  ...  2019     12   28
# 2019-12-29     32.5             7            0.8687  ...  2019     12   29
# 2019-12-30      0.0             8            0.6520  ...  2019     12   30
#
# [7371 rows x 32 columns]

# %%
# Separate observation precipitation and features
y = data['UR_PRCP'].to_numpy()
X = data.drop(columns = ['UR_PRCP']).to_numpy()
X_norm = (X - mean(X, axis=0)) / std(X, axis=0)

# Split the data into training and testing sets
train_X, test_X, train_y, test_y = train_test_split(X_norm, y, test_size = 0.3, random_state = 42)

# Linear regression model
model_LinearRegression = LinearRegression()
model_LinearRegression.fit(train_X, train_y)

LinearRegression_predict_y = model_LinearRegression.predict(test_X)
rmse_LinearRegression = sqrt(mean_squared_error(test_y, LinearRegression_predict_y))
print('RMSE of linear regression model: ', rmse_LinearRegression)

# Plot testing data and model prediction
plt.plot(test_y, '.', color='r', label='Observed')
plt.plot(LinearRegression_predict_y, '-', color='b', label='Predicted')
plt.legend(loc='upper left')
plt.xlabel('Data Points')
plt.ylabel('Total Precipitation (mm)')
plt.tight_layout()
plt.savefig(YOUR_DIRECTORY + 'LinearRegression_UR_PRCP.png', dpi=600)
# Out:
# RMSE of linear regression model:  15.4500793872643

# %%
plt.figure(figsize=(22, 4.5))
plt.plot(model_LinearRegression.coef_, '.-')
plt.grid()

# %% [markdown]
# # (5) UR_TMAX linear regression

# %%
# clean the data
data = UR_MJOIndices_df.drop(columns = ['UR_PRCP', 'UR_TMIN'])
data = data.dropna()
data
# Out:
# Date        UR_TMAX  MJOPhase_OLR  MJOAmplitude_OLR  ...  Year  Month  Day
# 1980-01-31     34.0             6            0.3975  ...  1980      1   31
# 1980-02-18     27.0             8            1.0633  ...  1980      2   18
# 1980-03-27     25.0             7            2.1177  ...  1980      3   27
# 1980-03-29     26.0             7            2.2260  ...  1980      3   29
# 1980-04-01     25.0             8            2.4393  ...  1980      4    1
# ...             ...           ...               ...  ...   ...    ...  ...
# 2019-12-21     33.4             5            0.5292  ...  2019     12   21
# 2019-12-26     34.4             6            1.2575  ...  2019     12   26
# 2019-12-28     38.8             7            0.8633  ...  2019     12   28
# 2019-12-29     38.5             7            0.8687  ...  2019     12   29
# 2019-12-30     36.4             8            0.6520  ...  2019     12   30
#
# [5625 rows x 32 columns]

# %%
# Separate observation precipitation and features
y = data['UR_TMAX'].to_numpy()
X = data.drop(columns = ['UR_TMAX']).to_numpy()
X_norm = (X - mean(X, axis=0)) / std(X, axis=0)

# Split the data into training and testing sets
train_X, test_X, train_y, test_y = train_test_split(X_norm, y, test_size = 0.3, random_state = 42)

# Linear regression model
model_LinearRegression = LinearRegression()
model_LinearRegression.fit(train_X, train_y)

LinearRegression_predict_y = model_LinearRegression.predict(test_X)
rmse_LinearRegression = sqrt(mean_squared_error(test_y, LinearRegression_predict_y))
print('RMSE of linear regression model: ', rmse_LinearRegression)

# Plot testing data and model prediction
plt.plot(test_y, '.', color='r', label='Observed')
plt.plot(LinearRegression_predict_y, '-', color='b', label='Predicted')
plt.legend(loc='upper left')
plt.xlabel('Data Points')
plt.ylabel('Maximum Temperature (C)')
plt.tight_layout()
plt.savefig(YOUR_DIRECTORY + 'LinearRegression_UR_TMAX.png', dpi=600)
# Out:
# RMSE of linear regression model:  4.898906257100224

# %%
plt.figure(figsize=(22, 4.5))
plt.plot(model_LinearRegression.coef_, '.-')
plt.grid()

# %% [markdown]
# # (6) UR_TMIN linear regression

# %%
# clean the data
data = UR_MJOIndices_df.drop(columns = ['UR_PRCP', 'UR_TMAX'])
data = data.dropna()
data
# Out:
# Date        UR_TMIN  MJOPhase_OLR  MJOAmplitude_OLR  ...  Year  Month  Day
# 1980-01-31     22.0             6            0.3975  ...  1980      1   31
# 1980-02-01     19.0             7            0.6582  ...  1980      2    1
# 1980-02-02     14.0             8            0.7567  ...  1980      2    2
# 1980-02-03     18.0             8            0.8586  ...  1980      2    3
# 1980-02-18     14.0             8            1.0633  ...  1980      2   18
# ...             ...           ...               ...  ...   ...    ...  ...
# 2019-12-25     13.5             6            1.3163  ...  2019     12   25
# 2019-12-26     20.0             6            1.2575  ...  2019     12   26
# 2019-12-27     20.6             6            1.1587  ...  2019     12   27
# 2019-12-29     20.2             7            0.8687  ...  2019     12   29
# 2019-12-30     23.4             8            0.6520  ...  2019     12   30
#
# [10113 rows x 32 columns]

# %%
# Separate observation precipitation and features
y = data['UR_TMIN'].to_numpy()
X = data.drop(columns = ['UR_TMIN']).to_numpy()
X_norm = (X - mean(X, axis=0)) / std(X, axis=0)

# Split the data into training and testing sets
train_X, test_X, train_y, test_y = train_test_split(X_norm, y, test_size = 0.3, random_state = 42)

# Linear regression model
model_LinearRegression = LinearRegression()
model_LinearRegression.fit(train_X, train_y)

LinearRegression_predict_y = model_LinearRegression.predict(test_X)
rmse_LinearRegression = sqrt(mean_squared_error(test_y, LinearRegression_predict_y))
print('RMSE of linear regression model: ', rmse_LinearRegression)

# Plot testing data and model prediction
plt.plot(test_y, '.', color='r', label='Observed')
plt.plot(LinearRegression_predict_y, '-', color='b', label='Predicted')
plt.legend(loc='upper left')
plt.xlabel('Data Points')
plt.ylabel('Minimum Temperature (C)')
plt.tight_layout()
plt.savefig(YOUR_DIRECTORY + 'LinearRegression_UR_TMIN.png', dpi=600)
# Out:
# RMSE of linear regression model:  4.837087128981131

# %%
plt.figure(figsize=(22, 4.5))
plt.plot(model_LinearRegression.coef_, '.-')
plt.grid()
